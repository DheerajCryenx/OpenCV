# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# <h2>Computer Vision and OpenCV</h2>
# <p>Advancement in the field of science and technology has been aiding exciting breakthroughs, most of which are centered around the world of Computer Vision. From face-recognition to object detection, Computer Vision is being utilized in remarkable ways to make everyday life easy, efficient and secure.</p>
# <p><b><i>OpenCV</i></b> is a computer vision library that combines numerous computer vision algorithms. It has eight main modules along with some helper modules such as FLANN, Google Wrapper etc. as seen below.</p>

# %% [markdown]
# ![8812OS_03_01.jpg](attachment:8812OS_03_01.jpg)

# %% [markdown]
# <p>You can learn more about these modules by checking out the documentation linked below. Other note worthy resources include; (Will be updating videos list weekly for updated content.)</p>
# <ul>
#     <li><a href="https://docs.opencv.org/master/index.html">OpenCV Documenation</a></li>
#     <li><a href="https://www.youtube.com/watch?v=vT1JzLTH4G4&list=PLf7L7Kg8_FNxHATtLwDceyh72QQL9pvpQ"> Importance of Computer Vision (0:00 - 3:37)</a></li>
#       <li><a href="https://www.youtube.com/watch?v=-4E2-0sxVUM&t=115s"> Computer Vision Crash Course</a></li>
# </ul>

# %% [markdown]
# <h2>OpenCV Installation and Setup Resources</h2>
# <ul>
#     <li><a href="http://web.cecs.pdx.edu/~fliu/courses/cs410/python-opencv.html">Anaconda Navigator</a></li>
#     <li><a href="https://www.geeksforgeeks.org/setup-opencv-with-pycharm-environment/">PyCharm</a></li>
# </ul>
